# %% [markdown]
# <a href="https://colab.research.google.com/github/kaizen36/nlp-with-transformers-notebooks/blob/main/fine-tuning-bert-minimal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# hide_output
! pip install transformers[torch]==4.16.2 datasets==2.8.0
# Out:
# Requirement already satisfied: transformers[torch]==4.16.2 in /usr/local/lib/python3.10/dist-packages (4.16.2)
# Requirement already satisfied: datasets==2.8.0 in /usr/local/lib/python3.10/dist-packages (2.8.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers[torch]==4.16.2) (3.12.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]==4.16.2) (0.16.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]==4.16.2) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]==4.16.2) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]==4.16.2) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]==4.16.2) (2022.10.31)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers[torch]==4.16.2) (2.27.1)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.10/dist-packages (from transformers[torch]==4.16.2) (0.0.53)
# Requirement already satisfied: tokenizers!=0.11.3,>=0.10.1 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]==4.16.2) (0.13.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]==4.16.2) (4.65.0)
# Requirement already satisfied: torch>=1.0 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]==4.16.2) (2.0.1+cu118)
# Requirement already satisfied: pyarrow>=6.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets==2.8.0) (9.0.0)
# Requirement already satisfied: dill<0.3.7 in /usr/local/lib/python3.10/dist-packages (from datasets==2.8.0) (0.3.6)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets==2.8.0) (1.5.3)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets==2.8.0) (3.2.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets==2.8.0) (0.70.14)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.10/dist-packages (from datasets==2.8.0) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets==2.8.0) (3.8.4)
# Requirement already satisfied: responses<0.19 in /usr/local/lib/python3.10/dist-packages (from datasets==2.8.0) (0.18.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==2.8.0) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==2.8.0) (2.0.12)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==2.8.0) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==2.8.0) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==2.8.0) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==2.8.0) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==2.8.0) (1.3.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers[torch]==4.16.2) (4.7.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[torch]==4.16.2) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[torch]==4.16.2) (2023.5.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[torch]==4.16.2) (3.4)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.0->transformers[torch]==4.16.2) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.0->transformers[torch]==4.16.2) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0->transformers[torch]==4.16.2) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0->transformers[torch]==4.16.2) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.0->transformers[torch]==4.16.2) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.0->transformers[torch]==4.16.2) (16.0.6)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets==2.8.0) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets==2.8.0) (2022.7.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from sacremoses->transformers[torch]==4.16.2) (1.16.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from sacremoses->transformers[torch]==4.16.2) (8.1.6)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from sacremoses->transformers[torch]==4.16.2) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.0->transformers[torch]==4.16.2) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.0->transformers[torch]==4.16.2) (1.3.0)

# %% [markdown]
# # Text Classification

# %% [markdown]
# ## The Dataset

# %%
# hide_output
from datasets import load_dataset

emotions = load_dataset("dair-ai/emotion")
# Out:
# Downloading builder script:   0%|          | 0.00/3.97k [00:00<?, ?B/s]
# Downloading metadata:   0%|          | 0.00/3.28k [00:00<?, ?B/s]
# Downloading readme:   0%|          | 0.00/8.78k [00:00<?, ?B/s]
# WARNING:datasets.builder:No config specified, defaulting to: emotion/split
# Downloading and preparing dataset emotion/split to /root/.cache/huggingface/datasets/dair-ai___emotion/split/1.0.0/cca5efe2dfeb58c1d098e0f9eeb200e9927d889b5a03c67097275dfb5fe463bd...
# Downloading data files:   0%|          | 0/3 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/592k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/74.0k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/74.9k [00:00<?, ?B/s]
# Extracting data files:   0%|          | 0/3 [00:00<?, ?it/s]
# Generating train split:   0%|          | 0/16000 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/2000 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/2000 [00:00<?, ? examples/s]
# Dataset emotion downloaded and prepared to /root/.cache/huggingface/datasets/dair-ai___emotion/split/1.0.0/cca5efe2dfeb58c1d098e0f9eeb200e9927d889b5a03c67097275dfb5fe463bd. Subsequent calls will reuse this data.
#   0%|          | 0/3 [00:00<?, ?it/s]

# %%
emotions
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['text', 'label'],
#         num_rows: 16000
#     })
#     validation: Dataset({
#         features: ['text', 'label'],
#         num_rows: 2000
#     })
#     test: Dataset({
#         features: ['text', 'label'],
#         num_rows: 2000
#     })
# })

# %% [markdown]
# ## From Text to Tokens

# %% [markdown]
# ### Subword Tokenization

# %%
# hide_output
from transformers import AutoTokenizer

model_ckpt = "distilbert-base-uncased"
tokenizer = AutoTokenizer.from_pretrained(model_ckpt)
# Out:
# Downloading:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/483 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/226k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/455k [00:00<?, ?B/s]

# %% [markdown]
# ### Tokenizing the Whole Dataset

# %% [markdown]
# To tokenize the whole corpus, we'll use the `map()` method of our `DatasetDict` object. We'll encounter this method many times throughout this book, as it provides a convenient way to apply a processing function to each element in a dataset. As we'll soon see, the `map()` method can also be used to create new rows and columns.
#
# To get started, the first thing we need is a processing function to tokenize our examples with:

# %%
def tokenize(batch):
    return tokenizer(batch["text"], padding=True, truncation=True)

# %% [markdown]
# Once we've defined a processing function, we can apply it across all the splits in the corpus in a single line of code:

# %%
# hide_output
emotions_encoded = emotions.map(tokenize, batched=True, batch_size=None)
# Out:
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]

# %% [markdown]
# ### Fine-Tuning Transformers

# %%
import torch
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# #### Loading a pretrained model

# %%
# hide_output
from transformers import AutoModelForSequenceClassification

num_labels = 6
model = (AutoModelForSequenceClassification
         .from_pretrained(model_ckpt, num_labels=num_labels)
         .to(device))
# Out:
# Downloading:   0%|          | 0.00/256M [00:00<?, ?B/s]
# Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertForSequenceClassification: ['vocab_projector.weight', 'vocab_layer_norm.weight', 'vocab_transform.weight', 'vocab_projector.bias', 'vocab_layer_norm.bias', 'vocab_transform.bias']
# - This IS expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
from sklearn.metrics import accuracy_score, f1_score

def compute_metrics(pred):
    labels = pred.label_ids
    preds = pred.predictions.argmax(-1)
    f1 = f1_score(labels, preds, average="weighted")
    acc = accuracy_score(labels, preds)
    return {"accuracy": acc, "f1": f1}

# %% [markdown]
# #### Training the model

# %% [markdown]
# If you're running this code in a Jupyter notebook, you can log in to the Hub with the following helper function:

# %%
# from huggingface_hub import notebook_login

# notebook_login()

# %%
from transformers import Trainer, TrainingArguments

batch_size = 64
logging_steps = len(emotions_encoded["train"]) // batch_size
model_name = f"{model_ckpt}-finetuned-emotion"
training_args = TrainingArguments(output_dir=model_name,
                                  num_train_epochs=2,
                                  learning_rate=2e-5,
                                  per_device_train_batch_size=batch_size,
                                  per_device_eval_batch_size=batch_size,
                                  weight_decay=0.01,
                                  evaluation_strategy="epoch",
                                  disable_tqdm=False,
                                  logging_steps=logging_steps,
                                  # push_to_hub=True,
                                  log_level="error")

# %%
from transformers import Trainer

trainer = Trainer(model=model, args=training_args,
                  compute_metrics=compute_metrics,
                  train_dataset=emotions_encoded["train"],
                  eval_dataset=emotions_encoded["validation"],
                  tokenizer=tokenizer)
trainer.train();
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use thePyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
#     <div>
#
#       <progress value='500' max='500' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [500/500 04:14, Epoch 2/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.813600</td>
#       <td>0.312467</td>
#       <td>0.906500</td>
#       <td>0.904425</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.252400</td>
#       <td>0.218648</td>
#       <td>0.927500</td>
#       <td>0.927557</td>
#     </tr>
#   </tbody>
# </table><p>

# %%
# hide_output
preds_output = trainer.predict(emotions_encoded["validation"])
# Out:
#     <div>
#
#       <progress value='32' max='32' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [32/32 00:04]
#     </div>

# %%
preds_output.metrics
# Out:
# {'test_loss': 0.21864773333072662,
#  'test_accuracy': 0.9275,
#  'test_f1': 0.9275566630183932,
#  'test_runtime': 4.432,
#  'test_samples_per_second': 451.263,
#  'test_steps_per_second': 7.22}

# %%
import numpy as np
y_preds = np.argmax(preds_output.predictions, axis=1)

# %% [markdown]
# #### Saving and sharing the model

# %%
#hide_output
# trainer.push_to_hub(commit_message="Training completed!")
# Out:
# 'https://huggingface.co/lewtun/distilbert-base-uncased-finetuned-emotion/commit/352c4147e4754f73a0b41f7b175f4a907270c9c9'
